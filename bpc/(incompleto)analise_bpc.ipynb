# %%
import dask.dataframe as dd

# %%
URL = 'C:/Users/lazar/Downloads/*.csv'

# %%
df = dd.read_csv(
    URL,
    assume_missing=True,
    sep=';',
    encoding='latin1',
    dtype={'CPF BENEFICIÁRIO': 'object',
           'NOME MUNICÍPIO': 'object',
           'UF': 'object'
    }
)

# %%
df.head()
# Out:
#    MÊS COMPETÊNCIA  MÊS REFERÊNCIA    UF  CÓDIGO MUNICÍPIO SIAFI  \
# 0         202301.0        202301.0  <NA>                     NaN
# 1         202301.0        202301.0  <NA>                     NaN
# 2         202301.0        202301.0  <NA>                     NaN
# 3         202301.0        202301.0  <NA>                     NaN
# 4         202301.0        202301.0  <NA>                     NaN
#
#   NOME MUNICÍPIO  NIS BENEFICIÁRIO CPF BENEFICIÁRIO  \
# 0           <NA>               NaN             <NA>
# 1           <NA>               NaN             <NA>
# 2           <NA>               NaN             <NA>
# 3           <NA>               NaN             <NA>
# 4           <NA>      1.167041e+10   ***.483.911-**
#
#                   NOME BENEFICIÁRIO  NIS REPRESENTANTE LEGAL  \
# 0  *** TITULAR MENOR DE 16 ANOS ***             2.675166e+10
# 1  *** TITULAR MENOR DE 16 ANOS ***             1.600270e+10
# 2  *** TITULAR MENOR DE 16 ANOS ***             1.652092e+10
# 3  *** TITULAR MENOR DE 16 ANOS ***             1.675889e+10
# 4        ADELAIDE MARCIA BUENO DIAS             1.167041e+10
#
#   CPF REPRESENTANTE LEGAL       NOME REPRESENTANTE LEGAL  NÚMERO BENEFÍCIO  \
# 0          ***.400.043-**  MARIA NADINE SARAIVA DE SOUSA      2.077096e+09
# 1          ***.891.900-**         DEBORA ALMEIDA PEREIRA      7.048113e+09
# 2          ***.634.031-**          LEIA DE FARIA CAETANO      2.012265e+09
# 3          ***.946.838-**           JANECLE SOARES SILVA      7.008136e+09
# 4          ***.483.911-**     ADELAIDE MARCIA BUENO DIAS      5.030052e+09
#
#   BENEFÍCIO CONCEDIDO JUDICIALMENTE VALOR PARCELA
# 0                               SIM       1302,00
# 1                               NÃO       1302,00
# 2                               SIM       1302,00
# 3                               NÃO       1302,60
# 4                               NÃO       1302,00

# %%
cols_removidas = [
    'CÓDIGO MUNICÍPIO SIAFI',
    'NIS BENEFICIÁRIO',
    'CPF BENEFICIÁRIO',
    'NOME BENEFICIÁRIO',
    'NIS REPRESENTANTE LEGAL',
    'CPF REPRESENTANTE LEGAL',
    'NOME REPRESENTANTE LEGAL',
    'NÚMERO BENEFÍCIO'
]

# %%
df.dtypes
# Out:
# MÊS COMPETÊNCIA                              float64
# MÊS REFERÊNCIA                               float64
# UF                                   string[pyarrow]
# CÓDIGO MUNICÍPIO SIAFI                       float64
# NOME MUNICÍPIO                       string[pyarrow]
# NIS BENEFICIÁRIO                             float64
# CPF BENEFICIÁRIO                     string[pyarrow]
# NOME BENEFICIÁRIO                    string[pyarrow]
# NIS REPRESENTANTE LEGAL                      float64
# CPF REPRESENTANTE LEGAL              string[pyarrow]
# NOME REPRESENTANTE LEGAL             string[pyarrow]
# NÚMERO BENEFÍCIO                             float64
# BENEFÍCIO CONCEDIDO JUDICIALMENTE    string[pyarrow]
# VALOR PARCELA                        string[pyarrow]
# dtype: object

# %%
df = df.drop(columns=cols_removidas)

# %%
df.dtypes
# Out:
# MÊS COMPETÊNCIA                              float64
# MÊS REFERÊNCIA                               float64
# UF                                   string[pyarrow]
# NOME MUNICÍPIO                       string[pyarrow]
# BENEFÍCIO CONCEDIDO JUDICIALMENTE    string[pyarrow]
# VALOR PARCELA                        string[pyarrow]
# dtype: object

# %%
dd.to_parquet(
    df, 
    './dados/bpc_2023_parquet/', 
    engine='pyarrow', 
    write_index=False
)
