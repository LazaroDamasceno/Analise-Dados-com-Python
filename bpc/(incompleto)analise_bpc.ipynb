# %%
import dask.dataframe as dd

# %%
URL = 'C:/Users/lazar/Downloads/*.csv'

# %%
df = dd.read_csv(
    URL,
    assume_missing=True,
    sep=';',
    encoding='latin1',
    dtype={'CPF BENEFICIÁRIO': 'object'}
)

# %%
df.head()
# Out:
#    MÊS COMPETÊNCIA  MÊS REFERÊNCIA  UF  CÓDIGO MUNICÍPIO SIAFI NOME MUNICÍPIO  \
# 0         202001.0        202001.0  AC                   643.0     ACRELANDIA
# 1         202001.0        202001.0  AC                   643.0     ACRELANDIA
# 2         202001.0        202001.0  AC                   643.0     ACRELANDIA
# 3         202001.0        202001.0  AC                   643.0     ACRELANDIA
# 4         202001.0        202001.0  AC                   643.0     ACRELANDIA
#
#                  NIS BENEFICIÁRIO                CPF BENEFICIÁRIO  \
# 0  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 1  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 2  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 3  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 4  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
#
#                 NOME BENEFICIÁRIO  NIS REPRESENTANTE LEGAL  \
# 0  ***Titular menor de 16 anos***             1.261181e+10
# 1  ***Titular menor de 16 anos***             2.672146e+10
# 2  ***Titular menor de 16 anos***             1.683289e+10
# 3  ***Titular menor de 16 anos***             2.121432e+10
# 4  ***Titular menor de 16 anos***             1.262532e+10
#
#   CPF REPRESENTANTE LEGAL          NOME REPRESENTANTE LEGAL  NÚMERO BENEFÍCIO  \
# 0          ***.063.782-**             PEDRO DANTAS DA SILVA      7.030465e+09
# 1                    <NA>        ALBERTINA BEZERRA DE SOUZA      7.003012e+09
# 2          ***.733.962-**         ELIZANGELA PEREIRA AMORIM      5.376219e+09
# 3          ***.563.542-**           ADRIANA AMORIM DA SILVA      7.042454e+09
# 4          ***.409.212-**  MARIA EDIANA OLIVEIRA DE ALMEIDA      5.240167e+09
#
#   BENEFÍCIO CONCEDIDO JUDICIALMENTE VALOR PARCELA
# 0                               NÃO       1039,00
# 1                               NÃO       1039,00
# 2                               SIM       1039,00
# 3                               SIM       1039,00
# 4                               NÃO       1039,00

# %%
cols_removidas = [
    'CÓDIGO MUNICÍPIO SIAFI',
    'NIS BENEFICIÁRIO',
    'CPF BENEFICIÁRIO',
    'NOME BENEFICIÁRIO',
    'NIS REPRESENTANTE LEGAL',
    'CPF REPRESENTANTE LEGAL',
    'NOME REPRESENTANTE LEGAL',
    'NÚMERO BENEFÍCIO'
]

# %%
df.dtypes
# Out:
# MÊS COMPETÊNCIA                              float64
# MÊS REFERÊNCIA                               float64
# UF                                   string[pyarrow]
# CÓDIGO MUNICÍPIO SIAFI                       float64
# NOME MUNICÍPIO                       string[pyarrow]
# NIS BENEFICIÁRIO                     string[pyarrow]
# CPF BENEFICIÁRIO                     string[pyarrow]
# NOME BENEFICIÁRIO                    string[pyarrow]
# NIS REPRESENTANTE LEGAL                      float64
# CPF REPRESENTANTE LEGAL              string[pyarrow]
# NOME REPRESENTANTE LEGAL             string[pyarrow]
# NÚMERO BENEFÍCIO                             float64
# BENEFÍCIO CONCEDIDO JUDICIALMENTE    string[pyarrow]
# VALOR PARCELA                        string[pyarrow]
# dtype: object

# %%
df = df.drop(columns=cols_removidas)

# %%
df.dtypes
# Out:
# MÊS COMPETÊNCIA                              float64
# MÊS REFERÊNCIA                               float64
# UF                                   string[pyarrow]
# NOME MUNICÍPIO                       string[pyarrow]
# BENEFÍCIO CONCEDIDO JUDICIALMENTE    string[pyarrow]
# VALOR PARCELA                        string[pyarrow]
# dtype: object

# %%
dd.to_parquet(
    df, 
    './dados/bpc_2020_parquet/', 
    engine='pyarrow', 
    write_index=False
)
# Out:
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)

# %% [markdown]
# 2019 -> 9,36 GB -> 11,05 MB
