# %%
import dask.dataframe as dd

# %%
df_dd = dd.read_csv(
    '*.csv',
    assume_missing=True,
    sep=';',
    encoding='latin1'
)

# %%
df_dd.head()
# Out:
#    MÊS COMPETÊNCIA  MÊS REFERÊNCIA  UF  CÓDIGO MUNICÍPIO SIAFI NOME MUNICÍPIO  \
# 0         202101.0        202101.0  AC                   643.0     ACRELANDIA
# 1         202101.0        202101.0  AC                   643.0     ACRELANDIA
# 2         202101.0        202101.0  AC                   643.0     ACRELANDIA
# 3         202101.0        202101.0  AC                   643.0     ACRELANDIA
# 4         202101.0        202101.0  AC                   643.0     ACRELANDIA
#
#                  NIS BENEFICIÁRIO                CPF BENEFICIÁRIO  \
# 0  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 1  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 2  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 3  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
# 4  ***Titular menor de 16 anos***  ***Titular menor de 16 anos***
#
#                 NOME BENEFICIÁRIO  NIS REPRESENTANTE LEGAL  \
# ...

# %%
df_dd.columns
# Out:
# Index(['MÊS COMPETÊNCIA', 'MÊS REFERÊNCIA', 'UF', 'CÓDIGO MUNICÍPIO SIAFI',
#        'NOME MUNICÍPIO', 'NIS BENEFICIÁRIO', 'CPF BENEFICIÁRIO',
#        'NOME BENEFICIÁRIO', 'NIS REPRESENTANTE LEGAL',
#        'CPF REPRESENTANTE LEGAL', 'NOME REPRESENTANTE LEGAL',
#        'NÚMERO BENEFÍCIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE',
#        'VALOR PARCELA'],
#       dtype='object')

# %%
df_dd = df_dd[['UF', 'NOME MUNICÍPIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE', 'VALOR PARCELA']]

# %%
df_dd.columns
# Out:
# Index(['UF', 'NOME MUNICÍPIO', 'BENEFÍCIO CONCEDIDO JUDICIALMENTE',
#        'VALOR PARCELA'],
#       dtype='object')

# %%
dd.to_parquet(
    df_dd,
    'bpc_2021',
    engine='pyarrow'
)
# Out:
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# c:\Users\lazar\AppData\Local\Programs\Python\Python314\Lib\site-packages\dask\dataframe\io\csv.py:77: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# ...
