# %%
import polars as pl
from glob import glob
import os

# %%
urls = [f'bpc_{ano}_parquet/*.parquet' for ano in range(2019, 2026)]
urls
# Out:
# ['bpc_2019_parquet/*.parquet',
#  'bpc_2020_parquet/*.parquet',
#  'bpc_2021_parquet/*.parquet',
#  'bpc_2022_parquet/*.parquet',
#  'bpc_2023_parquet/*.parquet',
#  'bpc_2024_parquet/*.parquet',
#  'bpc_2025_parquet/*.parquet']

# %%
pl.read_parquet(urls)
# Out:
# shape: (426_781_329, 6)
# ┌─────────────────┬────────────────┬─────┬────────────────┬─────────────────────┬───────────────┐
# │ MÊS COMPETÊNCIA ┆ MÊS REFERÊNCIA ┆ UF  ┆ NOME MUNICÍPIO ┆ BENEFÍCIO CONCEDIDO ┆ VALOR PARCELA │
# │ ---             ┆ ---            ┆ --- ┆ ---            ┆ JUDICIALME…         ┆ ---           │
# │ f64             ┆ f64            ┆ str ┆ str            ┆ ---                 ┆ str           │
# │                 ┆                ┆     ┆                ┆ str                 ┆               │
# ╞═════════════════╪════════════════╪═════╪════════════════╪═════════════════════╪═══════════════╡
# │ 201901.0        ┆ 201901.0       ┆ AC  ┆ ACRELANDIA     ┆ NÃO                 ┆ 998,00        │
# │ 201901.0        ┆ 201901.0       ┆ AC  ┆ ACRELANDIA     ┆ NÃO                 ┆ 998,00        │
# │ 201901.0        ┆ 201901.0       ┆ AC  ┆ ACRELANDIA     ┆ NÃO                 ┆ 998,00        │
# ...
