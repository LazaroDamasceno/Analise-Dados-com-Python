# %%
import polars as pl

# %%
pl.Config.set_tbl_cols(-1)
pl.Config.set_tbl_rows(-1)
# Out:
# polars.config.Config

# %% [markdown]
# # ETL E DATA WRANGLING

# %%
df = pl.scan_parquet('dados_parquet/*/*.parquet').collect()

# %%
df.head()
# Out:
# shape: (5, 15)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬────────┬───────┬───────┬───────┐
# │ ANO ┆ PES ┆ ALT ┆ MUN ┆ UF_ ┆ PAI ┆ EST ┆ SEX ┆ ESC ┆ VIN ┆ DIS ┆ ZONA_R ┆ MUN_R ┆ UF_RE ┆ PAIS_ │
# │ _NA ┆ O   ┆ URA ┆ _NA ┆ NAS ┆ S_N ┆ ADO ┆ O   ┆ OLA ┆ CUL ┆ PEN ┆ ESIDEN ┆ ESIDE ┆ SIDEN ┆ RESID │
# │ SCI ┆ --- ┆ --- ┆ SCI ┆ CIM ┆ ASC ┆ _CI ┆ --- ┆ RID ┆ ACA ┆ SA  ┆ CIAL   ┆ NCIA  ┆ CIA   ┆ ENCIA │
# │ MEN ┆ str ┆ str ┆ MEN ┆ ENT ┆ IME ┆ VIL ┆ str ┆ ADE ┆ O_A ┆ --- ┆ ---    ┆ ---   ┆ ---   ┆ ---   │
# │ TO  ┆     ┆     ┆ TO  ┆ O   ┆ NTO ┆ --- ┆     ┆ --- ┆ NO  ┆ str ┆ str    ┆ str   ┆ str   ┆ str   │
# │ --- ┆     ┆     ┆ --- ┆ --- ┆ --- ┆ str ┆     ┆ str ┆ --- ┆     ┆        ┆       ┆       ┆       │
# │ str ┆     ┆     ┆ str ┆ str ┆ str ┆     ┆     ┆     ┆ str ┆     ┆        ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╡
# │ 198 ┆ 95  ┆ 181 ┆ DES ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ PIRAS ┆ SP    ┆ BRASI │
# │ 9   ┆     ┆     ┆ CAL ┆     ┆ SIL ┆ tei ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ SUNUN ┆       ┆ L     │
# │     ┆     ┆     ┆ VAD ┆     ┆     ┆ ro  ┆     ┆ Méd ┆     ┆ pen ┆        ┆ GA    ┆       ┆       │
# │     ┆     ┆     ┆ O   ┆     ┆     ┆     ┆     ┆ io  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ 64  ┆ 173 ┆ CAT ┆ SP  ┆ BRA ┆ Cas ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ SAO   ┆ SP    ┆ BRASI │
# │ 9   ┆     ┆     ┆ AND ┆     ┆ SIL ┆ ado ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ PAULO ┆       ┆ L     │
# │     ┆     ┆     ┆ UVA ┆     ┆     ┆     ┆     ┆ Sup ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eri ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ or  ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ 82  ┆ 171 ┆ CAT ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ CATAN ┆ SP    ┆ BRASI │
# │ 9   ┆     ┆     ┆ AND ┆     ┆ SIL ┆ tei ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ DUVA  ┆       ┆ L     │
# │     ┆     ┆     ┆ UVA ┆     ┆     ┆ ro  ┆     ┆ Méd ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ io  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ nul ┆ nul ┆ SAN ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ Ens ┆ 200 ┆ Sem ┆ Urbana ┆ PIRAJ ┆ SP    ┆ BRASI │
# │ 9   ┆ l   ┆ l   ┆ TO  ┆     ┆ SIL ┆ tei ┆     ┆ ino ┆ 7   ┆ dis ┆        ┆ UI    ┆       ┆ L     │
# │     ┆     ┆     ┆ AND ┆     ┆     ┆ ro  ┆     ┆ Méd ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆ RE  ┆     ┆     ┆     ┆     ┆ io  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Com ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ to  ┆     ┆     ┆        ┆       ┆       ┆       │
# │ 198 ┆ nul ┆ nul ┆ PIR ┆ SP  ┆ BRA ┆ Sol ┆ M   ┆ 3ª  ┆ 200 ┆ Sem ┆ Urbana ┆ PIRAJ ┆ SP    ┆ BRASI │
# │ 9   ┆ l   ┆ l   ┆ AJU ┆     ┆ SIL ┆ tei ┆     ┆ Sér ┆ 7   ┆ dis ┆        ┆ UI    ┆       ┆ L     │
# │     ┆     ┆     ┆ I   ┆     ┆     ┆ ro  ┆     ┆ ie  ┆     ┆ pen ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ do  ┆     ┆ sa  ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Ens ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ino ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ Méd ┆     ┆     ┆        ┆       ┆       ┆       │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ io  ┆     ┆     ┆        ┆       ┆       ┆       │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴────────┴───────┴───────┴───────┘

# %%
for col in df.columns:
    tem_nulos = df.select(
        pl.col(col).null_count()
    ).item()
    if (tem_nulos > 0):
        print(f'Coluna {col} tem {tem_nulos} nulos.')
# Out:
# Coluna PESO tem 18598039 nulos.
# Coluna ALTURA tem 18588096 nulos.
# Coluna DISPENSA tem 474630 nulos.

# %%
df['DISPENSA'].unique()
# Out:
# shape: (4,)
# Series: 'DISPENSA' [str]
# [
# 	"Com dispensa"
# 	"null"
# 	null
# 	"Sem dispensa"
# ]

# %%
for col in df.columns:
    df = df.with_columns(
        pl.col(col).replace('null', None)
    )

# %%
df['DISPENSA'].unique()
# Out:
# shape: (3,)
# Series: 'DISPENSA' [str]
# [
# 	null
# 	"Com dispensa"
# 	"Sem dispensa"
# ]

# %%
df = df.with_columns(
    foi_convocado = pl.when(
        pl.col('DISPENSA') == 'Sem dispensa'
    ).then(True).otherwise(False)
).drop('DISPENSA')

# %%
df['foi_convocado'].unique()
# Out:
# shape: (2,)
# Series: 'foi_convocado' [bool]
# [
# 	false
# 	true
# ]

# %%
for col in df.columns:
    tem_nulos = df.select(
        pl.col(col).null_count()
    ).item()
    if (tem_nulos > 0):
        print(f'Coluna {col} tem {tem_nulos} nulos.')
# Out:
# Coluna PESO tem 20208318 nulos.
# Coluna ALTURA tem 20248089 nulos.

# %%
df.group_by('VINCULACAO_ANO').agg(
    pl.col('PESO').null_count().sum().alias('peso_qtd_nulos'),
    (pl.col('PESO').null_count().sum() / pl.col('PESO').len() * 100).round(2).alias('peso_qtd_nulos (%)'),
    pl.col('ALTURA').null_count().sum().alias('altura_qtd_nulos'),
    (pl.col('ALTURA').null_count().sum() / pl.col('ALTURA').len() * 100).round(2).alias('altura_qtd_nulos (%)'),
)
# Out:
# shape: (18, 5)
# ┌────────────────┬────────────────┬────────────────────┬──────────────────┬──────────────────────┐
# │ VINCULACAO_ANO ┆ peso_qtd_nulos ┆ peso_qtd_nulos (%) ┆ altura_qtd_nulos ┆ altura_qtd_nulos (%) │
# │ ---            ┆ ---            ┆ ---                ┆ ---              ┆ ---                  │
# │ str            ┆ u32            ┆ f64                ┆ u32              ┆ f64                  │
# ╞════════════════╪════════════════╪════════════════════╪══════════════════╪══════════════════════╡
# │ 2017           ┆ 1086345        ┆ 74.84              ┆ 1085981          ┆ 74.82                │
# │ 2015           ┆ 1431323        ┆ 79.52              ┆ 1431323          ┆ 79.52                │
# │ 2012           ┆ 1663139        ┆ 81.24              ┆ 1663103          ┆ 81.24                │
# │ 2023           ┆ 558646         ┆ 56.78              ┆ 558646           ┆ 56.78                │
# │ 2008           ┆ 1407721        ┆ 81.6               ┆ 1405414          ┆ 81.47                │
# │ 2010           ┆ 1355126        ┆ 79.92              ┆ 1355080          ┆ 79.92                │
# │ 2019           ┆ 1068967        ┆ 72.37              ┆ 1118640          ┆ 75.73                │
# │ 2007           ┆ 1311379        ┆ 81.15              ┆ 1304042          ┆ 80.7                 │
# │ 2018           ┆ 675646         ┆ 68.11              ┆ 675646           ┆ 68.11                │
# │ 2009           ┆ 1214815        ┆ 78.75              ┆ 1214744          ┆ 78.74                │
# │ 2016           ┆ 1385850        ┆ 79.34              ┆ 1385907          ┆ 79.35                │
# │ 2013           ┆ 1406961        ┆ 80.15              ┆ 1406944          ┆ 80.15                │
# │ 2021           ┆ 682262         ┆ 67.53              ┆ 682263           ┆ 67.53                │
# │ 2014           ┆ 1388130        ┆ 80.2               ┆ 1388120          ┆ 80.19                │
# │ 2011           ┆ 1423103        ┆ 79.71              ┆ 1423054          ┆ 79.71                │
# │ 2020           ┆ 887650         ┆ 68.1               ┆ 887886           ┆ 68.12                │
# │ 2022           ┆ 719943         ┆ 70.52              ┆ 719943           ┆ 70.52                │
# │ 2024           ┆ 541312         ┆ 61.13              ┆ 541353           ┆ 61.13                │
# └────────────────┴────────────────┴────────────────────┴──────────────────┴──────────────────────┘

# %%
df = df.drop(['PESO', 'ALTURA'])

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬────────┬──────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ANO ┆ MUN ┆ UF_ ┆ PAIS_N ┆ ESTADO ┆ SEXO ┆ ESCOL ┆ VINCU ┆ ZONA_ ┆ MUN_R ┆ UF_RE ┆ PAIS_ ┆ foi_c │
# │ _NA ┆ _NA ┆ NAS ┆ ASCIME ┆ _CIVIL ┆ ---  ┆ ARIDA ┆ LACAO ┆ RESID ┆ ESIDE ┆ SIDEN ┆ RESID ┆ onvoc │
# │ SCI ┆ SCI ┆ CIM ┆ NTO    ┆ ---    ┆ str  ┆ DE    ┆ _ANO  ┆ ENCIA ┆ NCIA  ┆ CIA   ┆ ENCIA ┆ ado   │
# │ MEN ┆ MEN ┆ ENT ┆ ---    ┆ str    ┆      ┆ ---   ┆ ---   ┆ L     ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ TO  ┆ TO  ┆ O   ┆ str    ┆        ┆      ┆ str   ┆ str   ┆ ---   ┆ str   ┆ str   ┆ str   ┆ bool  │
# │ --- ┆ --- ┆ --- ┆        ┆        ┆      ┆       ┆       ┆ str   ┆       ┆       ┆       ┆       │
# │ str ┆ str ┆ str ┆        ┆        ┆      ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪════════╪══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ PIRAS ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ CAL ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ SUNUN ┆       ┆ L     ┆       │
# │     ┆ VAD ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆ GA    ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ BRASIL ┆ Casado ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ SAO   ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ AND ┆     ┆        ┆        ┆      ┆ o Sup ┆       ┆ a     ┆ PAULO ┆       ┆ L     ┆       │
# │     ┆ UVA ┆     ┆        ┆        ┆      ┆ erior ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ CATAN ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ AND ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ DUVA  ┆       ┆ L     ┆       │
# │     ┆ UVA ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ TO  ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ UI    ┆       ┆ L     ┆       │
# │     ┆ AND ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ 3ª    ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ AJU ┆     ┆        ┆ ro     ┆      ┆ Série ┆       ┆ a     ┆ UI    ┆       ┆ L     ┆       │
# │     ┆ I   ┆     ┆        ┆        ┆      ┆ do    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Ensin ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ o     ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴────────┴──────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
df = df.with_columns(
    pl.col('ANO_NASCIMENTO').cast(pl.Int16),
    pl.col('MUN_NASCIMENTO').cast(pl.Categorical),
    pl.col('UF_NASCIMENTO').cast(pl.Categorical)
)

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬────────┬──────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ANO ┆ MUN ┆ UF_ ┆ PAIS_N ┆ ESTADO ┆ SEXO ┆ ESCOL ┆ VINCU ┆ ZONA_ ┆ MUN_R ┆ UF_RE ┆ PAIS_ ┆ foi_c │
# │ _NA ┆ _NA ┆ NAS ┆ ASCIME ┆ _CIVIL ┆ ---  ┆ ARIDA ┆ LACAO ┆ RESID ┆ ESIDE ┆ SIDEN ┆ RESID ┆ onvoc │
# │ SCI ┆ SCI ┆ CIM ┆ NTO    ┆ ---    ┆ str  ┆ DE    ┆ _ANO  ┆ ENCIA ┆ NCIA  ┆ CIA   ┆ ENCIA ┆ ado   │
# │ MEN ┆ MEN ┆ ENT ┆ ---    ┆ str    ┆      ┆ ---   ┆ ---   ┆ L     ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ TO  ┆ TO  ┆ O   ┆ str    ┆        ┆      ┆ str   ┆ str   ┆ ---   ┆ str   ┆ str   ┆ str   ┆ bool  │
# │ --- ┆ --- ┆ --- ┆        ┆        ┆      ┆       ┆       ┆ str   ┆       ┆       ┆       ┆       │
# │ i16 ┆ cat ┆ cat ┆        ┆        ┆      ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪════════╪══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ PIRAS ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ CAL ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ SUNUN ┆       ┆ L     ┆       │
# │     ┆ VAD ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆ GA    ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ BRASIL ┆ Casado ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ SAO   ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ AND ┆     ┆        ┆        ┆      ┆ o Sup ┆       ┆ a     ┆ PAULO ┆       ┆ L     ┆       │
# │     ┆ UVA ┆     ┆        ┆        ┆      ┆ erior ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ CATAN ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ AND ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ DUVA  ┆       ┆ L     ┆       │
# │     ┆ UVA ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ Ensin ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ TO  ┆     ┆        ┆ ro     ┆      ┆ o     ┆       ┆ a     ┆ UI    ┆       ┆ L     ┆       │
# │     ┆ AND ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆        ┆      ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ BRASIL ┆ Soltei ┆ M    ┆ 3ª    ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ BRASI ┆ true  │
# │ 9   ┆ AJU ┆     ┆        ┆ ro     ┆      ┆ Série ┆       ┆ a     ┆ UI    ┆       ┆ L     ┆       │
# │     ┆ I   ┆     ┆        ┆        ┆      ┆ do    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Ensin ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ o     ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆        ┆      ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴────────┴──────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
df = df.with_columns(
    nasceu_no_brasil = pl.when(
        pl.col('PAIS_NASCIMENTO') == 'Brasil'
    ).then(True).otherwise(False)
).with_columns(
    nasceu_residencia = pl.when(
        pl.col('PAIS_RESIDENCIA') == 'Brasil'
    ).then(True).otherwise(False)
).drop(['pais_nascimento'.upper(), 'pais_residencia'.upper()])

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬──────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ANO ┆ MUN ┆ UF_ ┆ ESTADO ┆ SEXO ┆ ESCOLA ┆ VINCU ┆ ZONA_ ┆ MUN_R ┆ UF_RE ┆ foi_c ┆ nasce ┆ nasce │
# │ _NA ┆ _NA ┆ NAS ┆ _CIVIL ┆ ---  ┆ RIDADE ┆ LACAO ┆ RESID ┆ ESIDE ┆ SIDEN ┆ onvoc ┆ u_no_ ┆ u_res │
# │ SCI ┆ SCI ┆ CIM ┆ ---    ┆ str  ┆ ---    ┆ _ANO  ┆ ENCIA ┆ NCIA  ┆ CIA   ┆ ado   ┆ brasi ┆ idenc │
# │ MEN ┆ MEN ┆ ENT ┆ str    ┆      ┆ str    ┆ ---   ┆ L     ┆ ---   ┆ ---   ┆ ---   ┆ l     ┆ ia    │
# │ TO  ┆ TO  ┆ O   ┆        ┆      ┆        ┆ str   ┆ ---   ┆ str   ┆ str   ┆ bool  ┆ ---   ┆ ---   │
# │ --- ┆ --- ┆ --- ┆        ┆      ┆        ┆       ┆ str   ┆       ┆       ┆       ┆ bool  ┆ bool  │
# │ i16 ┆ cat ┆ cat ┆        ┆      ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪══════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ Soltei ┆ M    ┆ Ensino ┆ 2007  ┆ Urban ┆ PIRAS ┆ SP    ┆ true  ┆ false ┆ false │
# │ 9   ┆ CAL ┆     ┆ ro     ┆      ┆ Médio  ┆       ┆ a     ┆ SUNUN ┆       ┆       ┆       ┆       │
# │     ┆ VAD ┆     ┆        ┆      ┆ Comple ┆       ┆       ┆ GA    ┆       ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆      ┆ to     ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Casado ┆ M    ┆ Ensino ┆ 2007  ┆ Urban ┆ SAO   ┆ SP    ┆ true  ┆ false ┆ false │
# │ 9   ┆ AND ┆     ┆        ┆      ┆ Superi ┆       ┆ a     ┆ PAULO ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆      ┆ or Com ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆      ┆ pleto  ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Soltei ┆ M    ┆ Ensino ┆ 2007  ┆ Urban ┆ CATAN ┆ SP    ┆ true  ┆ false ┆ false │
# │ 9   ┆ AND ┆     ┆ ro     ┆      ┆ Médio  ┆       ┆ a     ┆ DUVA  ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆      ┆ Comple ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆      ┆ to     ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ Soltei ┆ M    ┆ Ensino ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false │
# │ 9   ┆ TO  ┆     ┆ ro     ┆      ┆ Médio  ┆       ┆ a     ┆ UI    ┆       ┆       ┆       ┆       │
# │     ┆ AND ┆     ┆        ┆      ┆ Comple ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆      ┆ to     ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ Soltei ┆ M    ┆ 3ª     ┆ 2007  ┆ Urban ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false │
# │ 9   ┆ AJU ┆     ┆ ro     ┆      ┆ Série  ┆       ┆ a     ┆ UI    ┆       ┆       ┆       ┆       │
# │     ┆ I   ┆     ┆        ┆      ┆ do     ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆      ┆ Ensino ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆      ┆ Médio  ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴──────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
df = df.with_columns(
    pl.col('VINCULACAO_ANO').cast(pl.Int16),
    pl.col('MUN_RESIDENCIA').cast(pl.Categorical),
    pl.col('UF_RESIDENCIA').cast(pl.Categorical)
).with_columns(
    mora_zona_urbana = pl.when(
        pl.col('ZONA_RESIDENCIAL') == 'Urbana'
    ).then(True).otherwise(False)
).drop('ZONA_RESIDENCIAL')

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬──────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ANO ┆ MUN ┆ UF_ ┆ ESTADO ┆ SEXO ┆ ESCOLA ┆ VINCU ┆ MUN_R ┆ UF_RE ┆ foi_c ┆ nasce ┆ nasce ┆ mora_ │
# │ _NA ┆ _NA ┆ NAS ┆ _CIVIL ┆ ---  ┆ RIDADE ┆ LACAO ┆ ESIDE ┆ SIDEN ┆ onvoc ┆ u_no_ ┆ u_res ┆ zona_ │
# │ SCI ┆ SCI ┆ CIM ┆ ---    ┆ str  ┆ ---    ┆ _ANO  ┆ NCIA  ┆ CIA   ┆ ado   ┆ brasi ┆ idenc ┆ urban │
# │ MEN ┆ MEN ┆ ENT ┆ str    ┆      ┆ str    ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ l     ┆ ia    ┆ a     │
# │ TO  ┆ TO  ┆ O   ┆        ┆      ┆        ┆ i16   ┆ cat   ┆ cat   ┆ bool  ┆ ---   ┆ ---   ┆ ---   │
# │ --- ┆ --- ┆ --- ┆        ┆      ┆        ┆       ┆       ┆       ┆       ┆ bool  ┆ bool  ┆ bool  │
# │ i16 ┆ cat ┆ cat ┆        ┆      ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪══════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ Soltei ┆ M    ┆ Ensino ┆ 2007  ┆ PIRAS ┆ SP    ┆ true  ┆ false ┆ false ┆ true  │
# │ 9   ┆ CAL ┆     ┆ ro     ┆      ┆ Médio  ┆       ┆ SUNUN ┆       ┆       ┆       ┆       ┆       │
# │     ┆ VAD ┆     ┆        ┆      ┆ Comple ┆       ┆ GA    ┆       ┆       ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆      ┆ to     ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Casado ┆ M    ┆ Ensino ┆ 2007  ┆ SAO   ┆ SP    ┆ true  ┆ false ┆ false ┆ true  │
# │ 9   ┆ AND ┆     ┆        ┆      ┆ Superi ┆       ┆ PAULO ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆      ┆ or Com ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆      ┆ pleto  ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Soltei ┆ M    ┆ Ensino ┆ 2007  ┆ CATAN ┆ SP    ┆ true  ┆ false ┆ false ┆ true  │
# │ 9   ┆ AND ┆     ┆ ro     ┆      ┆ Médio  ┆       ┆ DUVA  ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆      ┆ Comple ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆      ┆ to     ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ Soltei ┆ M    ┆ Ensino ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  │
# │ 9   ┆ TO  ┆     ┆ ro     ┆      ┆ Médio  ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       │
# │     ┆ AND ┆     ┆        ┆      ┆ Comple ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆      ┆ to     ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ Soltei ┆ M    ┆ 3ª     ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  │
# │ 9   ┆ AJU ┆     ┆ ro     ┆      ┆ Série  ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       │
# │     ┆ I   ┆     ┆        ┆      ┆ do     ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆      ┆ Ensino ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆      ┆ Médio  ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴──────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
df = df.with_columns(
    e_homem = pl.when(
        pl.col('SEXO') == 'M'
    ).then(True).otherwise(False)
).drop('SEXO')

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ANO ┆ MUN ┆ UF_ ┆ ESTADO ┆ ESCOL ┆ VINCU ┆ MUN_R ┆ UF_RE ┆ foi_c ┆ nasce ┆ nasce ┆ mora_ ┆ e_hom │
# │ _NA ┆ _NA ┆ NAS ┆ _CIVIL ┆ ARIDA ┆ LACAO ┆ ESIDE ┆ SIDEN ┆ onvoc ┆ u_no_ ┆ u_res ┆ zona_ ┆ em    │
# │ SCI ┆ SCI ┆ CIM ┆ ---    ┆ DE    ┆ _ANO  ┆ NCIA  ┆ CIA   ┆ ado   ┆ brasi ┆ idenc ┆ urban ┆ ---   │
# │ MEN ┆ MEN ┆ ENT ┆ str    ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ l     ┆ ia    ┆ a     ┆ bool  │
# │ TO  ┆ TO  ┆ O   ┆        ┆ str   ┆ i16   ┆ cat   ┆ cat   ┆ bool  ┆ ---   ┆ ---   ┆ ---   ┆       │
# │ --- ┆ --- ┆ --- ┆        ┆       ┆       ┆       ┆       ┆       ┆ bool  ┆ bool  ┆ bool  ┆       │
# │ i16 ┆ cat ┆ cat ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ PIRAS ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ CAL ┆     ┆ ro     ┆ o     ┆       ┆ SUNUN ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ VAD ┆     ┆        ┆ Médio ┆       ┆ GA    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Casado ┆ Ensin ┆ 2007  ┆ SAO   ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AND ┆     ┆        ┆ o Sup ┆       ┆ PAULO ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆ erior ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ CATAN ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AND ┆     ┆ ro     ┆ o     ┆       ┆ DUVA  ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ TO  ┆     ┆ ro     ┆ o     ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ AND ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ Soltei ┆ 3ª    ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AJU ┆     ┆ ro     ┆ Série ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ I   ┆     ┆        ┆ do    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Ensin ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ o     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
df = df.with_columns(
    pl.col('ESTADO_CIVIL').replace({
        'ViÃºvo': 'Viúvo',
        'Desquitado': 'Divorciado',
        "Separado Judicialmente": 'Divorciado'
    }).cast(pl.Categorical)
)

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ANO ┆ MUN ┆ UF_ ┆ ESTADO ┆ ESCOL ┆ VINCU ┆ MUN_R ┆ UF_RE ┆ foi_c ┆ nasce ┆ nasce ┆ mora_ ┆ e_hom │
# │ _NA ┆ _NA ┆ NAS ┆ _CIVIL ┆ ARIDA ┆ LACAO ┆ ESIDE ┆ SIDEN ┆ onvoc ┆ u_no_ ┆ u_res ┆ zona_ ┆ em    │
# │ SCI ┆ SCI ┆ CIM ┆ ---    ┆ DE    ┆ _ANO  ┆ NCIA  ┆ CIA   ┆ ado   ┆ brasi ┆ idenc ┆ urban ┆ ---   │
# │ MEN ┆ MEN ┆ ENT ┆ cat    ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ l     ┆ ia    ┆ a     ┆ bool  │
# │ TO  ┆ TO  ┆ O   ┆        ┆ str   ┆ i16   ┆ cat   ┆ cat   ┆ bool  ┆ ---   ┆ ---   ┆ ---   ┆       │
# │ --- ┆ --- ┆ --- ┆        ┆       ┆       ┆       ┆       ┆       ┆ bool  ┆ bool  ┆ bool  ┆       │
# │ i16 ┆ cat ┆ cat ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ PIRAS ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ CAL ┆     ┆ ro     ┆ o     ┆       ┆ SUNUN ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ VAD ┆     ┆        ┆ Médio ┆       ┆ GA    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Casado ┆ Ensin ┆ 2007  ┆ SAO   ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AND ┆     ┆        ┆ o Sup ┆       ┆ PAULO ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆ erior ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ CATAN ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AND ┆     ┆ ro     ┆ o     ┆       ┆ DUVA  ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ TO  ┆     ┆ ro     ┆ o     ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ AND ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ Soltei ┆ 3ª    ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AJU ┆     ┆ ro     ┆ Série ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ I   ┆     ┆        ┆ do    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Ensin ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ o     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
substituicoes = {
    "Â°": "º",
    'Ã§âo': 'ção',
    'MÃ©dio': 'Médio',
    'Ã§Ã£o': 'ção',
    "PÃ³s": 'Pós',
    "PÃ³s": 'Pós'
}

# %%
df = df.with_columns(
    pl.col("ESCOLARIDADE").str.replace_many(
        substituicoes, 
        ascii_case_insensitive=True
    )
)

# %%
niveis_educacionais = [
    ['Analfabeto', 'Alfabetizado'],
    [
        '1° Ano - Ensino Fundamental', '1º Ano - Ensino Fundamental', '1ª Série do Ensino Fundamental',
        '2° Ano - Ensino Fundamental', '2º Ano - Ensino Fundamental', '2ª Série do Ensino Fundamental',
        '3° Ano - Ensino Fundamental', '3º Ano - Ensino Fundamental', '3ª Série do Ensino Fundamental',
        '4° Ano - Ensino Fundamental', '4º Ano - Ensino Fundamental', '4ª Série do Ensino Fundamental',
        '5° Ano - Ensino Fundamental', '5º Ano - Ensino Fundamental', '5ª Série do Ensino Fundamental',
        '6° Ano - Ensino Fundamental', '6º Ano - Ensino Fundamental', '6ª Série do Ensino Fundamental',
        '7° Ano - Ensino Fundamental', '7º Ano - Ensino Fundamental', '7ª Série do Ensino Fundamental',
        '8° Ano - Ensino Fundamental', '8º Ano - Ensino Fundamental', '8ª Série do Ensino Fundamental',
        '9° Ano - Ensino Fundamental', '9º Ano - Ensino Fundamental', '9ª Série do Ensino Fundamental',
        'Ensino Fundamental Completo'
    ],
    [
        '1° Ano - Ensino Médio', '1º Ano - Ensino Médio', '1ª Série do Ensino Médio',
        '2° Ano - Ensino Médio', '2º Ano - Ensino Médio', '2ª Série do Ensino Médio',
        '3° Ano - Ensino Médio', '3º Ano - Ensino Médio', '3ª Série do Ensino Médio',
        '4° Ano - Ensino Médio (Profissionalizante)', '4º Ano - Ensino Médio (Profissionalizante)', '4ª Série do Ensino Médio',
        'Ensino Médio Completo'
    ],
    [
        '1° Semestre - Ensino Superior', '1º Semestre - Ensino Superior', '1° Semestre do Ensino Superior',
        '2° Semestre - Ensino Superior', '2º Semestre - Ensino Superior', '2° Semestre do Ensino Superior',
        '3° Semestre - Ensino Superior', '3º Semestre - Ensino Superior', '3° Semestre do Ensino Superior',
        '4° Semestre - Ensino Superior', '4º Semestre - Ensino Superior', '4° Semestre do Ensino Superior',
        '5° Semestre - Ensino Superior', '5º Semestre - Ensino Superior', '5° Semestre do Ensino Superior',
        '6° Semestre - Ensino Superior', '6º Semestre - Ensino Superior', '6° Semestre do Ensino Superior',
        '7° Semestre - Ensino Superior', '7º Semestre - Ensino Superior', '7° Semestre do Ensino Superior',
        '8° Semestre - Ensino Superior', '8º Semestre - Ensino Superior', '8° Semestre do Ensino Superior',
        '9° Semestre - Ensino Superior', '9º Semestre - Ensino Superior', '9° Semestre do Ensino Superior',
        '10° Semestre - Ensino Superior', '10º Semestre - Ensino Superior', '10° Semestre do Ensino Superior',
        'Ensino Superior Completo'
    ],
    [
        'Pós-Graduação', 
        'Mestrado', 
        'Doutorado', 
        'Pós-Doutorado'
    ]
]

# %%
categorias_ordenadas = [item for sublista in niveis_educacionais for item in sublista]

# %%
df = df.with_columns(
    pl.col('ESCOLARIDADE').cast(pl.Enum(categorias_ordenadas))
)

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ANO ┆ MUN ┆ UF_ ┆ ESTADO ┆ ESCOL ┆ VINCU ┆ MUN_R ┆ UF_RE ┆ foi_c ┆ nasce ┆ nasce ┆ mora_ ┆ e_hom │
# │ _NA ┆ _NA ┆ NAS ┆ _CIVIL ┆ ARIDA ┆ LACAO ┆ ESIDE ┆ SIDEN ┆ onvoc ┆ u_no_ ┆ u_res ┆ zona_ ┆ em    │
# │ SCI ┆ SCI ┆ CIM ┆ ---    ┆ DE    ┆ _ANO  ┆ NCIA  ┆ CIA   ┆ ado   ┆ brasi ┆ idenc ┆ urban ┆ ---   │
# │ MEN ┆ MEN ┆ ENT ┆ cat    ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ l     ┆ ia    ┆ a     ┆ bool  │
# │ TO  ┆ TO  ┆ O   ┆        ┆ enum  ┆ i16   ┆ cat   ┆ cat   ┆ bool  ┆ ---   ┆ ---   ┆ ---   ┆       │
# │ --- ┆ --- ┆ --- ┆        ┆       ┆       ┆       ┆       ┆       ┆ bool  ┆ bool  ┆ bool  ┆       │
# │ i16 ┆ cat ┆ cat ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ PIRAS ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ CAL ┆     ┆ ro     ┆ o     ┆       ┆ SUNUN ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ VAD ┆     ┆        ┆ Médio ┆       ┆ GA    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Casado ┆ Ensin ┆ 2007  ┆ SAO   ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AND ┆     ┆        ┆ o Sup ┆       ┆ PAULO ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆ erior ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ CATAN ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AND ┆     ┆ ro     ┆ o     ┆       ┆ DUVA  ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ TO  ┆     ┆ ro     ┆ o     ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ AND ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ Soltei ┆ 3ª    ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AJU ┆     ┆ ro     ┆ Série ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ I   ┆     ┆        ┆ do    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Ensin ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ o     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %%
cols_originais = df.columns

# %%
cols_transformadas = [cols.lower() for cols in df.columns]

# %%
cols_renomeadas = dict(zip(cols_originais, cols_transformadas))
cols_renomeadas
# Out:
# {'ANO_NASCIMENTO': 'ano_nascimento',
#  'MUN_NASCIMENTO': 'mun_nascimento',
#  'UF_NASCIMENTO': 'uf_nascimento',
#  'ESTADO_CIVIL': 'estado_civil',
#  'ESCOLARIDADE': 'escolaridade',
#  'VINCULACAO_ANO': 'vinculacao_ano',
#  'MUN_RESIDENCIA': 'mun_residencia',
#  'UF_RESIDENCIA': 'uf_residencia',
#  'foi_convocado': 'foi_convocado',
#  'nasceu_no_brasil': 'nasceu_no_brasil',
#  'nasceu_residencia': 'nasceu_residencia',
#  'mora_zona_urbana': 'mora_zona_urbana',
#  'e_homem': 'e_homem'}

# %%
df = df.rename(cols_renomeadas)

# %%
df.head()
# Out:
# shape: (5, 13)
# ┌─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ ano ┆ mun ┆ uf_ ┆ estado ┆ escol ┆ vincu ┆ mun_r ┆ uf_re ┆ foi_c ┆ nasce ┆ nasce ┆ mora_ ┆ e_hom │
# │ _na ┆ _na ┆ nas ┆ _civil ┆ arida ┆ lacao ┆ eside ┆ siden ┆ onvoc ┆ u_no_ ┆ u_res ┆ zona_ ┆ em    │
# │ sci ┆ sci ┆ cim ┆ ---    ┆ de    ┆ _ano  ┆ ncia  ┆ cia   ┆ ado   ┆ brasi ┆ idenc ┆ urban ┆ ---   │
# │ men ┆ men ┆ ent ┆ cat    ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ l     ┆ ia    ┆ a     ┆ bool  │
# │ to  ┆ to  ┆ o   ┆        ┆ enum  ┆ i16   ┆ cat   ┆ cat   ┆ bool  ┆ ---   ┆ ---   ┆ ---   ┆       │
# │ --- ┆ --- ┆ --- ┆        ┆       ┆       ┆       ┆       ┆       ┆ bool  ┆ bool  ┆ bool  ┆       │
# │ i16 ┆ cat ┆ cat ┆        ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# ╞═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 198 ┆ DES ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ PIRAS ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ CAL ┆     ┆ ro     ┆ o     ┆       ┆ SUNUN ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ VAD ┆     ┆        ┆ Médio ┆       ┆ GA    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ O   ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Casado ┆ Ensin ┆ 2007  ┆ SAO   ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AND ┆     ┆        ┆ o Sup ┆       ┆ PAULO ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆ erior ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ CAT ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ CATAN ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AND ┆     ┆ ro     ┆ o     ┆       ┆ DUVA  ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ UVA ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ SAN ┆ SP  ┆ Soltei ┆ Ensin ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ TO  ┆     ┆ ro     ┆ o     ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ AND ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ RE  ┆     ┆        ┆ Compl ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ eto   ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │ 198 ┆ PIR ┆ SP  ┆ Soltei ┆ 3ª    ┆ 2007  ┆ PIRAJ ┆ SP    ┆ true  ┆ false ┆ false ┆ true  ┆ true  │
# │ 9   ┆ AJU ┆     ┆ ro     ┆ Série ┆       ┆ UI    ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆ I   ┆     ┆        ┆ do    ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Ensin ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ o     ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# │     ┆     ┆     ┆        ┆ Médio ┆       ┆       ┆       ┆       ┆       ┆       ┆       ┆       │
# └─────┴─────┴─────┴────────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┴───────┘

# %% [markdown]
# # EDA
