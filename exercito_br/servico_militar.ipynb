# %% [markdown]
# # 1. ETL & DATA WANGLING

# %% [markdown]
# # 2. EDA

# %% [markdown]
# # 3. ML

# %% [markdown]
# ## 3.1 CLUSTERIZAÇÃO: KMEANS OU DBSCAN

# %% [markdown]
# ## 3.2 REGRESSÃO LOGÍSTICA
