# %%
import polars as pl
import matplotlib.pyplot as plt

# %%
pl.Config.set_tbl_rows(-1)
pl.Config.set_tbl_cols(-1)
# Out:
# polars.config.Config

# %%
df = pl.read_excel('projecoes_2024_tab2_grupo_quinquenal.xlsx')

# %%
df.head()
# Out:
# shape: (5, 76)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ GRU ┆ SEX ┆ CÓD ┆ SIG ┆ LOC ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 200 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 201 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 202 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 203 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 204 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 205 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 206 ┆ 207 │
# ...

# %%
df.select(pl.col('SEXO').unique())
# Out:
# shape: (3, 1)
# ┌──────────┐
# │ SEXO     │
# │ ---      │
# │ str      │
# ╞══════════╡
# │ Ambos    │
# │ Homens   │
# │ Mulheres │
# └──────────┘

# %%
df.select(pl.col('LOCAL').unique())
# Out:
# shape: (33, 1)
# ┌─────────────────────┐
# │ LOCAL               │
# │ ---                 │
# │ str                 │
# ╞═════════════════════╡
# │ Nordeste            │
# │ Rio Grande do Norte │
# │ Brasil              │
# │ Paraná              │
# │ Mato Grosso do Sul  │
# │ Amapá               │
# │ São Paulo           │
# │ Sergipe             │
# │ Sul                 │
# │ Maranhão            │
# │ Minas Gerais        │
# │ Amazonas            │
# │ Espírito Santo      │
# │ Piauí               │
# │ Distrito Federal    │
# │ Goiás               │
# │ Norte               │
# │ Alagoas             │
# │ Rondônia            │
# │ Paraíba             │
# │ Mato Grosso         │
# │ Acre                │
# │ Rio Grande do Sul   │
# │ Tocantins           │
# │ Santa Catarina      │
# │ Rio de Janeiro      │
# │ Pernambuco          │
# │ Roraima             │
# │ Pará                │
# │ Ceará               │
# │ Centro-Oeste        │
# │ Sudeste             │
# ...

# %%
df = df.filter([
    pl.col('SEXO') == 'Ambos',
    pl.col('LOCAL') == 'Brasil'
])

# %%
print(df.select(pl.col('LOCAL').unique()))
print(df.select(pl.col('SEXO').unique()))
# Out:
# shape: (1, 1)
# ┌────────┐
# │ LOCAL  │
# │ ---    │
# │ str    │
# ╞════════╡
# │ Brasil │
# └────────┘
# shape: (1, 1)
# ┌───────┐
# │ SEXO  │
# │ ---   │
# │ str   │
# ╞═══════╡
# │ Ambos │
# └───────┘

# %%
print(df.columns)
# Out:
# ['GRUPO ETÁRIO', 'SEXO', 'CÓD.', 'SIGLA', 'LOCAL', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025', '2026', '2027', '2028', '2029', '2030', '2031', '2032', '2033', '2034', '2035', '2036', '2037', '2038', '2039', '2040', '2041', '2042', '2043', '2044', '2045', '2046', '2047', '2048', '2049', '2050', '2051', '2052', '2053', '2054', '2055', '2056', '2057', '2058', '2059', '2060', '2061', '2062', '2063', '2064', '2065', '2066', '2067', '2068', '2069', '2070']

# %%
df = df.drop(['SEXO', 'CÓD.', 'SIGLA', 'LOCAL'])

# %%
df = df.rename({
    'GRUPO ETÁRIO': 'grupo_etario'
})

# %%
print(df.columns)
# Out:
# ['grupo_etario', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025', '2026', '2027', '2028', '2029', '2030', '2031', '2032', '2033', '2034', '2035', '2036', '2037', '2038', '2039', '2040', '2041', '2042', '2043', '2044', '2045', '2046', '2047', '2048', '2049', '2050', '2051', '2052', '2053', '2054', '2055', '2056', '2057', '2058', '2059', '2060', '2061', '2062', '2063', '2064', '2065', '2066', '2067', '2068', '2069', '2070']

# %%
df_tidy = df.unpivot(
    index='grupo_etario',
    on=[str(x) for x in range(2000, 2071)],
    variable_name='ano',
    value_name='populacao_br'
)

# %%
df_tidy = df_tidy.with_columns(
    pl.col('ano').cast(int)
)

# %%
df_tidy.head()
# Out:
# shape: (5, 3)
# ┌──────────────┬──────┬──────────────┐
# │ grupo_etario ┆ ano  ┆ populacao_br │
# │ ---          ┆ ---  ┆ ---          │
# │ str          ┆ i64  ┆ i64          │
# ╞══════════════╪══════╪══════════════╡
# │  00-04       ┆ 2000 ┆ 17281547     │
# │  05-09       ┆ 2000 ┆ 17378990     │
# │  10-14       ┆ 2000 ┆ 17599378     │
# │  15-19       ┆ 2000 ┆ 17831344     │
# │  20-24       ┆ 2000 ┆ 16402228     │
# └──────────────┴──────┴──────────────┘

# %%
df_grouped = df_tidy.group_by('ano').agg(
    pl.col('populacao_br').sum()
)

# %%
df_grouped.head()
# Out:
# shape: (5, 2)
# ┌──────┬──────────────┐
# │ ano  ┆ populacao_br │
# │ ---  ┆ ---          │
# │ i64  ┆ i64          │
# ╞══════╪══════════════╡
# │ 2007 ┆ 189458827    │
# │ 2011 ┆ 196158610    │
# │ 2014 ┆ 200811131    │
# │ 2022 ┆ 210862983    │
# │ 2030 ┆ 216973093    │
# └──────┴──────────────┘

# %%
df_sorted = df_grouped.sort('ano', descending=False)

# %%
df_sorted.head()
# Out:
# shape: (5, 2)
# ┌──────┬──────────────┐
# │ ano  ┆ populacao_br │
# │ ---  ┆ ---          │
# │ i64  ┆ i64          │
# ╞══════╪══════════════╡
# │ 2000 ┆ 174695935    │
# │ 2001 ┆ 177003743    │
# │ 2002 ┆ 179228254    │
# │ 2003 ┆ 181377654    │
# │ 2004 ┆ 183469593    │
# └──────┴──────────────┘

# %%
anos = df_sorted.select(pl.col('ano')).to_series().to_list()
print(anos)
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070]

# %%
ano_pop_pico = df_sorted.filter(
    pl.col('populacao_br') == pl.col('populacao_br').max()
).row(0)[0]
ano_pop_pico
# Out:
# 2041

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x = df_sorted.select(pl.col('ano'))
y = df_sorted.select(pl.col('populacao_br'))

ax.plot(x, y, marker='o')
ax.grid()
ax.tick_params('x', rotation=90)
ax.set_xticks(anos)
ax.axvline(ano_pop_pico, color='red', linestyle='--')
ax.set_title('Projação da população brasileira (2000-2070)', fontweight='bold')
ax.set_ylabel('População projetada')
ax.set_xlabel('Ano')

plt.tight_layout()
fig.savefig('projecao_populacao_br.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df_sorted.filter(
    pl.col('populacao_br') == pl.col('populacao_br').min()
)
# Out:
# shape: (1, 2)
# ┌──────┬──────────────┐
# │ ano  ┆ populacao_br │
# │ ---  ┆ ---          │
# │ i64  ┆ i64          │
# ╞══════╪══════════════╡
# │ 2000 ┆ 174695935    │
# └──────┴──────────────┘

# %%
df_sorted.filter(
    pl.col('populacao_br') == pl.col('populacao_br').max()
)
# Out:
# shape: (1, 2)
# ┌──────┬──────────────┐
# │ ano  ┆ populacao_br │
# │ ---  ┆ ---          │
# │ i64  ┆ i64          │
# ╞══════╪══════════════╡
# │ 2041 ┆ 220425299    │
# └──────┴──────────────┘

# %%
df_sorted.filter(
    pl.col('ano') == 2070
)
# Out:
# shape: (1, 2)
# ┌──────┬──────────────┐
# │ ano  ┆ populacao_br │
# │ ---  ┆ ---          │
# │ i64  ┆ i64          │
# ╞══════╪══════════════╡
# │ 2070 ┆ 199228708    │
# └──────┴──────────────┘

# %%
df_sorted.filter(
    pl.col('ano') == 2013
)
# Out:
# shape: (1, 2)
# ┌──────┬──────────────┐
# │ ano  ┆ populacao_br │
# │ ---  ┆ ---          │
# │ i64  ┆ i64          │
# ╞══════╪══════════════╡
# │ 2013 ┆ 199226702    │
# └──────┴──────────────┘
