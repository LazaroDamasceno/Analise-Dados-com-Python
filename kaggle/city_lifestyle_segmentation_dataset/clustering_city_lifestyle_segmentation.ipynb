# %% [markdown]
# CRIANDO O DATAFRAME

# %% [markdown]
# CHECANDO SE HÁ VALORES NULOS

# %% [markdown]
# VERIFICANDO O COEFICIENTE DE ASSIMETRIA

# %% [markdown]
# VERIFICANDO PONTOS EXTREMOS

# %% [markdown]
# DESCOBRIR SE USO  KMEANS E DBSCAN

# %% [markdown]
# KMEANS
